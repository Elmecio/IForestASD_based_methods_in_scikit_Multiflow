# %% [markdown]
# # Comparison of Original IForestASD, SADWIN IFA, PADWIN IFA, and NDKSWIN

# %% [markdown]
# L'objectif est de voir comment les 4 méthodes se comportent avec différents jeux de données.
# * SAWIN IFA (Scores based ADWIN on IForestASD) utilise le score des données sur la base du modèle créé avec IForest ASD dans les fenêtres précédentes. Ce score est utilisé par ADWIN pour vérifier si le modèle drift pour pas. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.
# * PAWIN IFA (Prediction based ADWIN on IForestASD) utilise la classification des données sur la base du modèle créé avec IForest ASD dans les fenêtres précédentes. Cette classification est utilisée par ADWIN pour vérifier si le modèle drift pour pas. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.
# * NDKSWIN IFA (N-Dimensional KSWIN on IForestASD) utilise les données de la fenêtre courante pour détecter si elles drift sur au moins une colonne. NDKSWIN est une adaptation de KSWIN de scikit-multiflow pour les données à n dimensions. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.

# %% [markdown]
# ## Install skmultiflow if needed
# You need to install git

# %%
#print("scikit-multiflow package installation")
#!pip install -U git+https://github.com/scikit-multiflow/scikit-multiflow

# %%
try:
    import skmultiflow
except ImportError as e:
    print("scikit-multiflow package installation")
    # !pip install -U git+https://github.com/scikit-multiflow/scikit-multiflow

# %% [markdown]
# ## Importations and configurations

# %%
# %matplotlib notebook
import matplotlib as plt
plt.interactive(True)
from source import functions
func = functions.Comparison()
import datetime
#from skmultiflow.data import AnomalySineGenerator

# %% [markdown]
# ## General parameters for the evaluation

# %%
#************************ Execution settings *******************************
window_sizes = [100, 500]
n_estimators = [30]
#window_sizes = [50, 100]
#n_estimators = [20, 30]
#window_sizes = [50]
#n_estimators = [30]
#max_sample = 1000 # Total size of data to examine (windows number = max_sample/window)
#window = 100 # Number of sample in one window, window size.
#n_estimator = 30 # Number of itree in the random forest
execution_number = 1 # Number of execution because of the random character of IForest
anomaly_threshold = 0.5 # Anomaly threshold to decide which is anomaly or not
max_sample = 10000 # Total size of data to examine (windows number = max_sample/window)
n_wait = max_sample # The evaluation step size
# Used metric in the evaluation. Attention to use the metrics availlable in skmultiflow
metrics=['accuracy', 'f1', 'precision', 'recall', 'true_vs_predicted', 'kappa', 'kappa_m', 'running_time', 'model_size']

#************************ Stream data settings *******************************
window_save_size = 100
window_number = round((max_sample/window_save_size),0) # The number of window to save on .csv file

# Parameters for NDWSIN IFA
alpha=0.01
n_dimensions=2 # Number of dimensions to use for the test of the drift concept (normally 50% of m)
n_tested_samples=0.1 # Percentage of data to pick in the window to test the drift concept
fixed_checked_dimension = False # IF False, dimension will be choose randomly, if not on the 
fixed_checked_sample=False

# %% [markdown]
# ## Execution Function

# %%
def execute_comparision():
    file_path = func.save_stream_data_generated(stream=stream, window = window_save_size, 
                                                result_folder=test_name, window_number = window_number)
    for window in window_sizes:
        stream2 = func.get_file_stream(path=file_path)
        for n_estimator in n_estimators:
            print("")
            print("******************************** Window = "+str(window)+" and n_estimator = "+str(n_estimator)+" ********************************")
            func.run_IForestASDs_comparison2(execution_number=execution_number, stream=stream2, 
                                            stream_n_features=stream.n_features, window = window, 
                             estimators = n_estimator, anomaly = anomaly_threshold, drift_rate = drift_rate, 
                             result_folder=test_name, max_sample=max_sample, n_wait=n_wait, metrics=metrics,
                             #n_estimators_updated=n_estimators_updated, updated_randomly=updated_randomly,
                            alpha=alpha, n_dimensions=n_dimensions, n_tested_samples=n_tested_samples,
                            fixed_checked_dimension = fixed_checked_dimension, fixed_checked_sample=fixed_checked_sample)
    
    directory_path = 'results/'+str(test_name)
    func.merge_file2(folder_path=directory_path, output_file = 'output.csv',skiprows=(4 + 4))

# %% [markdown]
# ## Applied On Simple Stream Dataset
# ### Idea and waitting results
# ### Results
# #### Model updating
# #### Method performances
#
# ### Summary

# %%
dataset_name = "Generator"
test_name = dataset_name+'_'+str(datetime.datetime.now())
drift_rate = 0
]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.4105
# O_IFA - Kappa        : -0.0171
# O_IFA - Kappa M      : -0.6721
# O_IFA - Precision: 0.3247
# O_IFA - Recall: 0.3097
# O_IFA - F1 score: 0.3856
# O_IFA - Training time (s)  : 10.58
# O_IFA - Testing time  (s)  : 3245.11
# O_IFA - Total time    (s)  : 3255.69
# O_IFA - Size (kB)          : 2081.3262
# SADWIN_IFA - Accuracy     : 0.4220
# SADWIN_IFA - Kappa        : 0.0196
# SADWIN_IFA - Kappa M      : -0.6394
# SADWIN_IFA - Precision: 0.3430
# SADWIN_IFA - Recall: 0.3254
# SADWIN_IFA - F1 score: 0.3974
# SADWIN_IFA - Training time (s)  : 5.59
# SADWIN_IFA - Testing time  (s)  : 3202.95
# SADWIN_IFA - Total time    (s)  : 3208.53
# SADWIN_IFA - Size (kB)          : 2116.4971
# PADWIN_IFA - Accuracy     : 0.4168
# PADWIN_IFA - Kappa        : -0.0045
# PADWIN_IFA - Kappa M      : -0.6542
# PADWIN_IFA - Precision: 0.3307
# PADWIN_IFA - Recall: 0.3151
# PADWIN_IFA - F1 score: 0.3917
# PADWIN_IFA - Training time (s)  : 5.41
# PADWIN_IFA - Testing time  (s)  : 3191.85
# PADWIN_IFA - Total time    (s)  : 3197.25
# PADWIN_IFA - Size (kB)          : 2164.9229
# NDKSWIN_IFA - Accuracy     : 0.4011
# NDKSWIN_IFA - Kappa        : -0.0262
# NDKSWIN_IFA - Kappa M      : -0.6987
# NDKSWIN_IFA - Precision: 0.3198
# NDKSWIN_IFA - Recall: 0.3058
# NDKSWIN_IFA - F1 score: 0.3771
# NDKSWIN_IFA - Training time (s)  : 1.11
# NDKSWIN_IFA - Testing time  (s)  : 3195.58
# NDKSWIN_IFA - Total time    (s)  : 3196.69
# NDKSWIN_IFA - Size (kB)          : 2022.0664
#
# Please find the result on results/Generator_2020-12-12 17:04:54.199595/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/Generator_2020-12-12 17:04:54.199595/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/Generator_2020-12-12 17:04:54.199595/output.csv_full.csv

# %% [markdown]
# ## Applied On Stream data containning anomalies
# ### Idea and waitting results
# The idea of using a stream data with anomalies and without drift is to test both methods on a anomaly environnement.
# Normally, SADWIN IForestASD or PADWIN IForestASD method will not update his model (It will be a good result) and it will have better or similar performances like Original IForestASD. The model_size and the total time can be upper than Orignal IForestASD ones because it take time to use ADWIN.
# ### Results
# #### Model updating
# - Original IForest ASD always update its model in every window because we give it the exact percentage of noise in every stream
# - SADWIN update its model for the last-1 window
# - PADWIN never update its model (This is the real waittng behavior)
# #### Method performances
#
# ### Summary

# %%
dataset_name = "AnomalySineGenerator"
test_name = dataset_name+'_'+str(datetime.datetime.now())
n_samples=max_sample
anomalies_percentage = 0.1
drift_rate = anomalies_percentage
n_anomalies= int(n_samples*anomalies_percentage)
#print(str(n_anomalies))
stream = func.get_anomalies_data_generated(n_samples=n_samples, n_anomalies=n_anomalies, contextual=False,
                 n_contextual=0.0, shift=4, noise=0.0, replace=True, random_state=None)
execute_comparision()
# Out:
# Please find the data used on results/AnomalySineGenerator_2020-12-12 21:25:46.220513/AnomalySineGenerator_2020-12-12 21:25:46.220513_dataUsed.csv
#
# ******************************** Window = 100 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #------------------- [5%] [81.01s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [179.59s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [282.08s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ####---------------- [20%] [380.67s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #####--------------- [25%] [477.20s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [577.89s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [675.98s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [771.19s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [866.95s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [965.33s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [1062.88s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [1168.51s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  #############------- [65%] [1274.10s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##############------ [70%] [1379.81s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###############----- [75%] [1481.77s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ################---- [80%] [1581.31s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [1682.91s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [1784.84s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [1883.37s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [1981.05s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.
# PADWIN_IFA - Testing time  (s)  : 2870.83
# PADWIN_IFA - Total time    (s)  : 2875.88
# PADWIN_IFA - Size (kB)          : 2079.1064
# NDKSWIN_IFA - Accuracy     : 0.7260
# NDKSWIN_IFA - Kappa        : 0.3073
# NDKSWIN_IFA - Kappa M      : -1.8782
# NDKSWIN_IFA - Precision: 0.4297
# NDKSWIN_IFA - Recall: 0.5529
# NDKSWIN_IFA - F1 score: 0.5841
# NDKSWIN_IFA - Training time (s)  : 1.06
# NDKSWIN_IFA - Testing time  (s)  : 2864.91
# NDKSWIN_IFA - Total time    (s)  : 2865.96
# NDKSWIN_IFA - Size (kB)          : 2053.6758
#
# Please find the result on results/AnomalySineGenerator_2020-12-12 21:25:46.220513/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/AnomalySineGenerator_2020-12-12 21:25:46.220513/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/AnomalySineGenerator_2020-12-12 21:25:46.220513/output.csv_full.csv

# %% [markdown]
# ## Applied On Simple ConceptDrift Stream Dataset

# %% [markdown]
# ### When drift start one window and is in the window

# %%
dataset_name = "DriftStreamGenerator"
test_name = dataset_name+'_'+str(datetime.datetime.now())
drift_rate = 0.0
stream = func.get_dataset(dataset_name=dataset_name, classification_function=0, noise_percentage=0.0, random_state=1,
                         drift_classification_function = 5, drift_random_state = 112, drift_noise_percentage = 0.0,
                          drift_start_position = 100, drift_width = 50, n_num_features = 2, n_cat_features = 0)
execute_comparision()
# Out:
# Please find the data used on results/DriftStreamGenerator_2020-12-13 01:10:16.404894/DriftStreamGenerator_2020-12-13 01:10:16.404894_dataUsed.csv
#
# ******************************** Window = 100 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #------------------- [5%] [72.76s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [162.93s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [254.21s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ####---------------- [20%] [349.85s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #####--------------- [25%] [443.13s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [538.96s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  #######------------- [35%] [631.21s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [725.34s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [817.90s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [911.61s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [1006.48s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [1102.22s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [1196.41s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ##############------ [70%] [1289.64s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###############----- [75%] [1385.08s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ################---- [80%] [1478.06s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [1574.89s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [1668.48s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [1763.45s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [1857.24s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.5521
# O_IFA - Kappa        : 0.0651
# O_IFA - Kappa M      : -0.1616
# O_IFA - Precision: 0.3551
# O_IFA - Recall: 0.3515
# O_IFA - F1 score: 0.4710
# O_IFA - Training time (s)  : 10.83
# O_IFA - Testing time  (s)  : 469.16
# O_IFA - Total time    (s)  : 480.00
# O_IFA - Size (kB)          : 670.6230
# SADWIN_IFA - Accuracy     : 0.5485
# SADWIN_IFA - Kappa        : 0.0431
# SADWIN_IFA - Kappa M      : -0.1709
# SADWIN_IFA - Precision: 0.3478
# SADWIN_IFA - Recall: 0.3439
# SADWIN_IFA - F1 score: 0.4607
# SADWIN_IFA - Training time (s)  : 4.42
# SADWIN_IFA - Testing time  (s)  : 453.97
# SADWIN_IFA - Total time    (s)  : 458.39
# SADWIN_IFA - Size (kB)          : 716.4424
# PADWIN_IFA - Accuracy     : 0.5673
# PADWIN_IFA - Kappa        : 0.1002
# PADWIN_IFA - Kappa M      : -0.1221
# PADWIN_IFA - Precision: 0.3669
# PADWIN_IFA - Recall: 0.3635
# PADWIN_IFA - F1 score: 0.4869
# PADWIN_IFA - Training time (s)  : 4.32
# PADWIN_IFA - Testing time  (s)  : 459.60
# PADWIN_IFA - Total time    (s)  : 463.92
# PADWIN_IFA - Size (kB)          : 721.9541
# NDKSWIN_IFA - Accuracy     : 0.5554
# NDKSWIN_IFA - Kappa        : 0.0721
# NDKSWIN_IFA - Kappa M      : -0.1530
# NDKSWIN_IFA - Precision: 0.3574
# NDKSWIN_IFA - Recall: 0.3539
# NDKSWIN_IFA - F1 score: 0.4742
# NDKSWIN_IFA - Training time (s)  : 1.40
# NDKSWIN_IFA - Testing time  (s)  : 452.20
# NDKSWIN_IFA - Total time    (s)  : 453.60
# NDKSWIN_IFA - Size (kB)          : 701.1484
#
# Please find the result on results/DriftStreamGenerator_2020-12-13 01:10:16.404894/result_Number0_for_WS100_NE30updated_count.csv
#
# Please find evaluation results here results/DriftStreamGenerator_2020-12-13 01:10:16.404894/result_Number0_for_WS100_NE30.csv
#
# ******************************** Window = 500 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  #------------------- [5%] [0.09s]
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [579.36s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [1163.57s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ####---------------- [20%] [1747.21s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #####--------------- [25%] [2325.47s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [2893.82s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [3477.68s]
# The model was updated by training a new iForest with the version : AnomalyRate
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:5556: RuntimeWarning: ks_2samp: Exact calculation incurred large rounding error. Switching to mode=asymp
#   RuntimeWarning)
#  ########------------ [40%] [4053.67s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [4622.98s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [5194.17s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ###########--------- [55%] [5772.34s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [6437.46s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [7096.89s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##############------ [70%] [7756.70s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###############----- [75%] [8419.90s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ################---- [80%] [9090.31s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [9669.74s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [10267.07s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [10862.15s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [11462.22s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.5015
# O_IFA - Kappa        : 0.0650
# O_IFA - Kappa M      : -0.2928
# O_IFA - Precision: 0.3579
# O_IFA - Recall: 0.3407
# O_IFA - F1 score: 0.4574
# O_IFA - Training time (s)  : 9.90
# O_IFA - Testing time  (s)  : 2909.31
# O_IFA - Total time    (s)  : 2919.21
# O_IFA - Size (kB)          : 2281.6660
# SADWIN_IFA - Accuracy     : 0.5177
# SADWIN_IFA - Kappa        : 0.1141
# SADWIN_IFA - Kappa M      : -0.2508
# SADWIN_IFA - Precision: 0.3786
# SADWIN_IFA - Recall: 0.3601
# SADWIN_IFA - F1 score: 0.4768
# SADWIN_IFA - Training time (s)  : 5.30
# SADWIN_IFA - Testing time  (s)  : 2845.51
# SADWIN_IFA - Total time    (s)  : 2850.81
# SADWIN_IFA - Size (kB)          : 2268.6221
# PADWIN_IFA - Accuracy     : 0.5190
# PADWIN_IFA - Kappa        : 0.0880
# PADWIN_IFA - Kappa M      : -0.2474
# PADWIN_IFA - Precision: 0.3659
# PADWIN_IFA - Recall: 0.3490
# PADWIN_IFA - F1 score: 0.4707
# PADWIN_IFA - Training time (s)  : 5.26
# PADWIN_IFA - Testing time  (s)  : 2823.70
# PADWIN_IFA - Total time    (s)  : 2828.96
# PADWIN_IFA - Size (kB)          : 2377.4189
# NDKSWIN_IFA - Accuracy     : 0.5167
# NDKSWIN_IFA - Kappa        : 0.0688
# NDKSWIN_IFA - Kappa M      : -0.2534
# NDKSWIN_IFA - Precision: 0.3584
# NDKSWIN_IFA - Recall: 0.3415
# NDKSWIN_IFA - F1 score: 0.4637
# NDKSWIN_IFA - Training time (s)  : 1.67
# NDKSWIN_IFA - Testing time  (s)  : 2860.02
# NDKSWIN_IFA - Total time    (s)  : 2861.69
# NDKSWIN_IFA - Size (kB)          : 2658.6328
#
# Please find the result on results/DriftStreamGenerator_2020-12-13 01:10:16.404894/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/DriftStreamGenerator_2020-12-13 01:10:16.404894/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/DriftStreamGenerator_2020-12-13 01:10:16.404894/output.csv_full.csv

# %% [markdown]
# ## When drift is in one window and don't start the window

# %%
dataset_name = "DriftStreamGenerator"
test_name = dataset_name+'_'+str(datetime.datetime.now())
drift_rate = 0.0
stream = func.get_dataset(dataset_name=dataset_name, classification_function=0, noise_percentage=0.0, random_state=1,
                         drift_classification_function = 3, drift_random_state = 112, drift_noise_percentage = 0.0,
                          drift_start_position = 110, drift_width = 50, n_num_features = 2, n_cat_features = 0)
execute_comparision()
# Out:
# Please find the data used on results/DriftStreamGenerator_2020-12-13 04:52:21.486115/DriftStreamGenerator_2020-12-13 04:52:21.486115_dataUsed.csv
#
# ******************************** Window = 100 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #------------------- [5%] [76.38s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [167.64s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [256.77s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ####---------------- [20%] [352.85s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #####--------------- [25%] [453.48s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [550.32s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [644.82s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:5556: RuntimeWarning: ks_2samp: Exact calculation incurred large rounding error. Switching to mode=asymp
#   RuntimeWarning)
#  ########------------ [40%] [740.02s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [835.11s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [931.80s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [1022.32s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [1115.76s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [1209.16s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##############------ [70%] [1307.90s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###############----- [75%] [1402.33s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ################---- [80%] [1499.66s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [1593.25s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ##################-- [90%] [1687.87s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [1785.07s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [1882.38s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.5397
# O_IFA - Kappa        : 0.0371
# O_IFA - Kappa M      : -0.1922
# O_IFA - Precision: 0.3455
# O_IFA - Recall: 0.3420
# O_IFA - F1 score: 0.4583
# O_IFA - Training time (s)  : 11.07
# O_IFA - Testing time  (s)  : 472.83
# O_IFA - Total time    (s)  : 483.90
# O_IFA - Size (kB)          : 707.6895
# SADWIN_IFA - Accuracy     : 0.5583
# SADWIN_IFA - Kappa        : 0.1213
# SADWIN_IFA - Kappa M      : -0.1440
# SADWIN_IFA - Precision: 0.3744
# SADWIN_IFA - Recall: 0.3724
# SADWIN_IFA - F1 score: 0.4937
# SADWIN_IFA - Training time (s)  : 4.52
# SADWIN_IFA - Testing time  (s)  : 474.40
# SADWIN_IFA - Total time    (s)  : 478.91
# SADWIN_IFA - Size (kB)          : 664.1924
# PADWIN_IFA - Accuracy     : 0.5689
# PADWIN_IFA - Kappa        : 0.0744
# PADWIN_IFA - Kappa M      : -0.1166
# PADWIN_IFA - Precision: 0.3591
# PADWIN_IFA - Recall: 0.3539
# PADWIN_IFA - F1 score: 0.4739
# PADWIN_IFA - Training time (s)  : 4.27
# PADWIN_IFA - Testing time  (s)  : 453.92
# PADWIN_IFA - Total time    (s)  : 458.19
# PADWIN_IFA - Size (kB)          : 728.2627
# NDKSWIN_IFA - Accuracy     : 0.5332
# NDKSWIN_IFA - Kappa        : 0.0251
# NDKSWIN_IFA - Kappa M      : -0.2090
# NDKSWIN_IFA - Precision: 0.3414
# NDKSWIN_IFA - Recall: 0.3380
# NDKSWIN_IFA - F1 score: 0.4529
# NDKSWIN_IFA - Training time (s)  : 1.44
# NDKSWIN_IFA - Testing time  (s)  : 458.61
# NDKSWIN_IFA - Total time    (s)  : 460.05
# NDKSWIN_IFA - Size (kB)          : 648.8047
#
# Please find the result on results/DriftStreamGenerator_2020-12-13 04:52:21.486115/result_Number0_for_WS100_NE30updated_count.csv
#
# Please find evaluation results here results/DriftStreamGenerator_2020-12-13 04:52:21.486115/result_Number0_for_WS100_NE30.csv
#
# ******************************** Window = 500 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  #------------------- [5%] [0.08s]
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [580.73s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [1152.17s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ####---------------- [20%] [1751.02s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #####--------------- [25%] [2338.39s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [2914.14s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [3502.68s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [4088.95s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [4640.05s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [5189.58s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [5738.65s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [6306.03s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [6851.37s]
# The model was updated by training a new iForest with the version : AnomalyRate
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:5556: RuntimeWarning: ks_2samp: Exact calculation incurred large rounding error. Switching to mode=asymp
#   RuntimeWarning)
#  ##############------ [70%] [7400.00s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ###############----- [75%] [7950.97s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ################---- [80%] [8498.91s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [9052.33s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [9605.78s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [10155.89s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [10704.61s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.4860
# O_IFA - Kappa        : 0.0333
# O_IFA - Kappa M      : -0.3310
# O_IFA - Precision: 0.3459
# O_IFA - Recall: 0.3288
# O_IFA - F1 score: 0.4424
# O_IFA - Training time (s)  : 9.12
# O_IFA - Testing time  (s)  : 2691.88
# O_IFA - Total time    (s)  : 2701.00
# O_IFA - Size (kB)          : 2282.7715
# SADWIN_IFA - Accuracy     : 0.4884
# SADWIN_IFA - Kappa        : 0.0176
# SADWIN_IFA - Kappa M      : -0.3248
# SADWIN_IFA - Precision: 0.3397
# SADWIN_IFA - Recall: 0.3228
# SADWIN_IFA - F1 score: 0.4384
# SADWIN_IFA - Training time (s)  : 4.77
# SADWIN_IFA - Testing time  (s)  : 2660.28
# SADWIN_IFA - Total time    (s)  : 2665.05
# SADWIN_IFA - Size (kB)          : 2394.4033
# PADWIN_IFA - Accuracy     : 0.5027
# PADWIN_IFA - Kappa        : 0.0714
# PADWIN_IFA - Kappa M      : -0.2880
# PADWIN_IFA - Precision: 0.3606
# PADWIN_IFA - Recall: 0.3432
# PADWIN_IFA - F1 score: 0.4595
# PADWIN_IFA - Training time (s)  : 4.67
# PADWIN_IFA - Testing time  (s)  : 2672.90
# PADWIN_IFA - Total time    (s)  : 2677.58
# PADWIN_IFA - Size (kB)          : 2310.5830
# NDKSWIN_IFA - Accuracy     : 0.4551
# NDKSWIN_IFA - Kappa        : -0.0110
# NDKSWIN_IFA - Kappa M      : -0.4110
# NDKSWIN_IFA - Precision: 0.3293
# NDKSWIN_IFA - Recall: 0.3121
# NDKSWIN_IFA - F1 score: 0.4171
# NDKSWIN_IFA - Training time (s)  : 1.17
# NDKSWIN_IFA - Testing time  (s)  : 2658.49
# NDKSWIN_IFA - Total time    (s)  : 2659.67
# NDKSWIN_IFA - Size (kB)          : 2316.3906
#
# Please find the result on results/DriftStreamGenerator_2020-12-13 04:52:21.486115/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/DriftStreamGenerator_2020-12-13 04:52:21.486115/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/DriftStreamGenerator_2020-12-13 04:52:21.486115/output.csv_full.csv

# %% [markdown]
# ## When drift don't start a window but is between two windows

# %%
dataset_name = "DriftStreamGenerator"
test_name = dataset_name+'_'+str(datetime.datetime.now())
drift_rate = 0.0
stream = func.get_dataset(dataset_name=dataset_name, classification_function=0, noise_percentage=0.0, random_state=1,
                         drift_classification_function = 5, drift_random_state = 112, drift_noise_percentage = 0.0,
                          drift_start_position = 175, drift_width = 100, n_num_features = 2, n_cat_features = 0)
execute_comparision()
# Out:
# Please find the data used on results/DriftStreamGenerator_2020-12-13 08:22:13.958907/DriftStreamGenerator_2020-12-13 08:22:13.958907_dataUsed.csv
#
# ******************************** Window = 100 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #------------------- [5%] [72.41s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [161.26s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:5556: RuntimeWarning: ks_2samp: Exact calculation incurred large rounding error. Switching to mode=asymp
#   RuntimeWarning)
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [250.12s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ####---------------- [20%] [339.58s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #####--------------- [25%] [428.86s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [519.06s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [608.64s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [698.20s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [787.09s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [875.73s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [966.88s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [1058.40s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [1147.97s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##############------ [70%] [1236.75s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###############----- [75%] [1325.54s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ################---- [80%] [1414.87s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [1506.20s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [1598.95s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [1688.66s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [1778.35s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.5362
# O_IFA - Kappa        : 0.0252
# O_IFA - Kappa M      : -0.1938
# O_IFA - Precision: 0.3415
# O_IFA - Recall: 0.3380
# O_IFA - F1 score: 0.4528
# O_IFA - Training time (s)  : 10.60
# O_IFA - Testing time  (s)  : 446.93
# O_IFA - Total time    (s)  : 457.53
# O_IFA - Size (kB)          : 692.8730
# SADWIN_IFA - Accuracy     : 0.5340
# SADWIN_IFA - Kappa        : 0.0479
# SADWIN_IFA - Kappa M      : -0.1995
# SADWIN_IFA - Precision: 0.3492
# SADWIN_IFA - Recall: 0.3460
# SADWIN_IFA - F1 score: 0.4628
# SADWIN_IFA - Training time (s)  : 4.22
# SADWIN_IFA - Testing time  (s)  : 436.30
# SADWIN_IFA - Total time    (s)  : 440.52
# SADWIN_IFA - Size (kB)          : 667.7666
# PADWIN_IFA - Accuracy     : 0.5476
# PADWIN_IFA - Kappa        : 0.0768
# PADWIN_IFA - Kappa M      : -0.1645
# PADWIN_IFA - Precision: 0.3589
# PADWIN_IFA - Recall: 0.3559
# PADWIN_IFA - F1 score: 0.4758
# PADWIN_IFA - Training time (s)  : 4.12
# PADWIN_IFA - Testing time  (s)  : 440.61
# PADWIN_IFA - Total time    (s)  : 444.73
# PADWIN_IFA - Size (kB)          : 674.4150
# NDKSWIN_IFA - Accuracy     : 0.5476
# NDKSWIN_IFA - Kappa        : 0.0416
# NDKSWIN_IFA - Kappa M      : -0.1645
# NDKSWIN_IFA - Precision: 0.3472
# NDKSWIN_IFA - Recall: 0.3433
# NDKSWIN_IFA - F1 score: 0.4598
# NDKSWIN_IFA - Training time (s)  : 1.46
# NDKSWIN_IFA - Testing time  (s)  : 432.83
# NDKSWIN_IFA - Total time    (s)  : 434.30
# NDKSWIN_IFA - Size (kB)          : 754.9609
#
# Please find the result on results/DriftStreamGenerator_2020-12-13 08:22:13.958907/result_Number0_for_WS100_NE30updated_count.csv
#
# Please find evaluation results here results/DriftStreamGenerator_2020-12-13 08:22:13.958907/result_Number0_for_WS100_NE30.csv
#
# ******************************** Window = 500 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  #------------------- [5%] [0.07s]
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [542.13s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [1081.37s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ####---------------- [20%] [1622.10s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  #####--------------- [25%] [2169.34s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [2715.41s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [3257.94s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [3805.05s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [4348.49s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [4893.88s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [5435.39s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [5982.15s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [6527.12s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##############------ [70%] [7071.62s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###############----- [75%] [7614.89s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ################---- [80%] [8159.54s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [8705.57s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [9249.92s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [9793.39s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [10337.52s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.4818
# O_IFA - Kappa        : 0.0209
# O_IFA - Kappa M      : -0.3336
# O_IFA - Precision: 0.3412
# O_IFA - Recall: 0.3237
# O_IFA - F1 score: 0.4372
# O_IFA - Training time (s)  : 9.25
# O_IFA - Testing time  (s)  : 2626.04
# O_IFA - Total time    (s)  : 2635.29
# O_IFA - Size (kB)          : 2315.4473
# SADWIN_IFA - Accuracy     : 0.5116
# SADWIN_IFA - Kappa        : 0.0717
# SADWIN_IFA - Kappa M      : -0.2571
# SADWIN_IFA - Precision: 0.3598
# SADWIN_IFA - Recall: 0.3424
# SADWIN_IFA - F1 score: 0.4630
# SADWIN_IFA - Training time (s)  : 4.64
# SADWIN_IFA - Testing time  (s)  : 2560.60
# SADWIN_IFA - Total time    (s)  : 2565.24
# SADWIN_IFA - Size (kB)          : 2314.2822
# PADWIN_IFA - Accuracy     : 0.4889
# PADWIN_IFA - Kappa        : 0.0300
# PADWIN_IFA - Kappa M      : -0.3153
# PADWIN_IFA - Precision: 0.3445
# PADWIN_IFA - Recall: 0.3270
# PADWIN_IFA - F1 score: 0.4425
# PADWIN_IFA - Training time (s)  : 4.58
# PADWIN_IFA - Testing time  (s)  : 2536.02
# PADWIN_IFA - Total time    (s)  : 2540.60
# PADWIN_IFA - Size (kB)          : 2369.5283
# NDKSWIN_IFA - Accuracy     : 0.4904
# NDKSWIN_IFA - Kappa        : 0.0375
# NDKSWIN_IFA - Kappa M      : -0.3115
# NDKSWIN_IFA - Precision: 0.3474
# NDKSWIN_IFA - Recall: 0.3299
# NDKSWIN_IFA - F1 score: 0.4453
# NDKSWIN_IFA - Training time (s)  : 1.13
# NDKSWIN_IFA - Testing time  (s)  : 2593.96
# NDKSWIN_IFA - Total time    (s)  : 2595.10
# NDKSWIN_IFA - Size (kB)          : 2274.8633
#
# Please find the result on results/DriftStreamGenerator_2020-12-13 08:22:13.958907/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/DriftStreamGenerator_2020-12-13 08:22:13.958907/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/DriftStreamGenerator_2020-12-13 08:22:13.958907/output.csv_full.csv
