# %% [markdown]
# # Test the KSWIN function to detect drift in stream

# %% [markdown]
# To compute the best parameters for NDKSWIN : number of dimension and percentage of data to compute

# %% [markdown]
# ## Install skmultiflow if needed
# You need to install git

# %%
#print("scikit-multiflow package installation")
#!pip install -U git+https://github.com/scikit-multiflow/scikit-multiflow

# %%
try:
    import skmultiflow
except ImportError as e:
    print("scikit-multiflow package installation")
    # !pip install -U git+https://github.com/scikit-multiflow/scikit-multiflow

# %% [markdown]
# ## Importations and configurations

# %%
# %matplotlib notebook
import matplotlib as plt
plt.interactive(True)
from source import functions
func = functions.Comparison()
from source import ndkswin as ndk
import datetime
import copy
import pandas as pd
import numpy as np

# %% [markdown]
# ## General parameters for the evaluation

# %% [markdown]
# ## Execution Function
# https://github.com/scikit-multiflow/scikit-multiflow/blob/master/src/skmultiflow/drift_detection/kswin.py
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ks_2samp.html

# %%
#************************ Execution settings *******************************

window = 100 # Number of sample in one window, window size.
max_sample = 10000 # Total size of data to examine (windows number = max_sample/window)
window_number = int(max_sample/window) # The number of window to save on .csv file
#window_number = 3 # The number of window to save on .csv file

# %%
def execute_NDKSWIN(stream, window_size=100, window_number=1000, n_dimensions=1, n_tested_samples=0.1):
    #from skmultiflow.drift_detection import KSWIN
    import pandas as pd
    import numpy as np
    # Initialize KSWIN and a data stream
    #first_window = stream.next_sample(window_size)[0][:,0]
    first_window = stream.next_sample(window_size)[0]
    #print(first_window)
    #print(type(first_window))
    #ndkswin = ndk.NDKSWIN(alpha=0.01, data=first_window, n_dimensions=1, n_tested_samples=(1/window_size),
    #                      fixed_checked_dimension = True, fixed_checked_sample=True)
    ndkswin = ndk.NDKSWIN(alpha=0.01, data=first_window, n_dimensions=n_dimensions, n_tested_samples=n_tested_samples,
                          fixed_checked_dimension = False, fixed_checked_sample=False)
    # Store detections
    detections = []
    # Process stream via KSWIN and print detections
    for i in range(window_number-1):
        #data = stream.next_sample(window_size)
        data = stream.next_sample(window_size)
        batch = data[0]
        ndkswin.add_element(batch)
        if ndkswin.detected_change():
            #print("\rIteration {}".format(i))
            #print("\r KSWINReject Null Hyptheses")
            detections.append(i)
            #ndkswin.reset()
            #ndkswin = ndk.NDKSWIN(alpha=0.01, data=batch, n_dimensions=1, n_tested_samples=0.1,
            #              fixed_checked_dimension = True, fixed_checked_sample=True)
    #print("Drift detected in window n° "+str(detections))
    print("Number of detections: "+str(len(detections)))
    return len(detections)

# %% [markdown]
# ## Applied On Simple ConceptDrift Stream Dataset

# %%
dataset_name = "DriftStreamGenerator"
test_name = dataset_name+'_'+str(datetime.datetime.now())

stream = func.get_dataset(dataset_name=dataset_name, classification_function=0, noise_percentage=0.0, random_state=1,
                         drift_classification_function = 3, drift_random_state = 112, drift_noise_percentage = 0.0,
                          drift_start_position = 101, drift_width = 50, n_num_features = 2, n_cat_features = 0)

file_path = func.save_stream_data_generated(stream=stream, window = window, result_folder=test_name, 
                                                 window_number = window_number)

test = []
for n_dimension in range(1,9+1,1):
    for n_tested_sample in np.arange(0.1, 1, 0.1):

        stream, stream2, stream3 = func.get_file_stream2(path=file_path)
        print("")
        print("****NDKSWIN Execution Random with n_dimension = "+str(n_dimension)+" n_tested_sample = "
              +str(n_tested_sample)+"*******")
        detection = execute_NDKSWIN(stream=stream3, window_size=window, window_number=window_number, 
                         n_dimensions=n_dimension, n_tested_samples=n_tested_sample)
        test.append([n_dimension, n_tested_sample, detection])
results_drift = pd.DataFrame(test, columns=["n_dimension", "n_tested_sample(%)", "detection_number"])
print(results_drift)
# Out:
# Please find the data used on results/DriftStreamGenerator_2020-12-03 13:42:14.202151/DriftStreamGenerator_2020-12-03 13:42:14.202151_dataUsed.csv
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.1*******
# Number of detections: 9
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.2*******
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:5556: RuntimeWarning: ks_2samp: Exact calculation incurred large rounding error. Switching to mode=asymp
#   RuntimeWarning)
# Number of detections: 8
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.30000000000000004*******
# Number of detections: 15
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.4*******
# Number of detections: 23
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.5*******
# Number of detections: 21
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.6*******
# Number of detections: 26
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.7000000000000001*******
# Number of detections: 31
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.8*******
# Number of detections: 36
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.9*******
# Number of detections: 28
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.1*******
# Number of detections: 6
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.2*******
# Number of detections: 17
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.30000000000000004*******
# Number of detections: 21
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.4*******
# Number of detections: 31
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.5*******
# Number of detections: 31
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.6*******
# Number of detections: 36
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.7000000000000001*******
# Number of detections: 38
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.8*******
# Number of detections: 47
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.9*******
# Number of detections: 56
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.1*******
# Number of detections: 9
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.2*******
# Number of detections: 18
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.30000000000000004*******
# Number of detections: 22
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.4*******
# Number of detections: 34
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.5*******
# Number of detections: 35
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.6*******
# Number of detections: 40
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.7000000000000001*******
# Number of detections: 47
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.8*******
# Number of detections: 53
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.9*******
# Number of detections: 54
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.1*******
# Number of detections: 10
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.2*******
# Number of detections: 19
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.30000000000000004*******
# Number of detections: 24
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.4*******
# Number of detections: 32
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.5*******
# Number of detections: 39
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.6*******
# Number of detections: 43
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.7000000000000001*******
# Number of detections: 49
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.8*******
# Number of detections: 59
#
# ****NDKSWIN Execution Random with n_dimension = 4 n_tested_sample = 0.9*******
# Number of detections: 56
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.1*******
# Number of detections: 12
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.2*******
# Number of detections: 18
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.30000000000000004*******
# Number of detections: 27
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.4*******
# Number of detections: 35
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.5*******
# Number of detections: 42
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.6*******
# Number of detections: 45
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.7000000000000001*******
# Number of detections: 49
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.8*******
# Number of detections: 55
#
# ****NDKSWIN Execution Random with n_dimension = 5 n_tested_sample = 0.9*******
# Number of detections: 72
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.1*******
# Number of detections: 10
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.2*******
# Number of detections: 21
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.30000000000000004*******
# Number of detections: 31
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.4*******
# Number of detections: 35
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.5*******
# Number of detections: 45
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.6*******
# Number of detections: 48
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.7000000000000001*******
# Number of detections: 50
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.8*******
# Number of detections: 56
#
# ****NDKSWIN Execution Random with n_dimension = 6 n_tested_sample = 0.9*******
# Number of detections: 66
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.1*******
# Number of detections: 13
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.2*******
# Number of detections: 20
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.30000000000000004*******
# Number of detections: 29
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.4*******
# Number of detections: 40
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.5*******
# Number of detections: 46
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.6*******
# Number of detections: 49
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.7000000000000001*******
# Number of detections: 50
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.8*******
# Number of detections: 70
#
# ****NDKSWIN Execution Random with n_dimension = 7 n_tested_sample = 0.9*******
# Number of detections: 75
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.1*******
# Number of detections: 12
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.2*******
# Number of detections: 22
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.30000000000000004*******
# Number of detections: 31
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.4*******
# Number of detections: 41
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.5*******
# Number of detections: 48
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.6*******
# Number of detections: 48
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.7000000000000001*******
# Number of detections: 50
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.8*******
# Number of detections: 69
#
# ****NDKSWIN Execution Random with n_dimension = 8 n_tested_sample = 0.9*******
# Number of detections: 80
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.1*******
# Number of detections: 12
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.2*******
# Number of detections: 22
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.30000000000000004*******
# Number of detections: 30
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.4*******
# Number of detections: 39
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.5*******
# Number of detections: 47
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.6*******
# Number of detections: 48
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.7000000000000001*******
# Number of detections: 52
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.8*******
# Number of detections: 67
#
# ****NDKSWIN Execution Random with n_dimension = 9 n_tested_sample = 0.9*******
# Number of detections: 79
#     n_dimension  n_tested_sample(%)  detection_number
# 0             1                 0.1                 9
# 1             1                 0.2                 8
# 2             1                 0.3                15
# 3             1                 0.4                23
# 4             1                 0.5                21
# ..          ...                 ...               ...
# 76            9                 0.5                47
# 77            9                 0.6                48
# 78            9                 0.7                52
# 79            9                 0.8                67
# 80            9                 0.9                79
#
# [81 rows x 3 columns]

# %% [markdown]
# ## Applied On Simple Stream Dataset

# %%
dataset_name = "Generator"
test_name = dataset_name+'_'+str(datetime.datetime.now())

stream = func.get_dataset(dataset_name=dataset_name, classification_function=0,noise_percentage=0.0, random_state=1)

file_path = func.save_stream_data_generated(stream=stream, window = window, result_folder=test_name, 
                                                 window_number = window_number)
test = []
for n_dimension in range(1,3+1,1):
    for n_tested_sample in np.arange(0.1, 1, 0.1):

        stream, stream2, stream3 = func.get_file_stream2(path=file_path)
        print("")
        print("****NDKSWIN Execution Random with n_dimension = "+str(n_dimension)+" n_tested_sample = "
              +str(n_tested_sample)+"*******")
        detection = execute_NDKSWIN(stream=stream3, window_size=window, window_number=window_number, 
                         n_dimensions=n_dimension, n_tested_samples=n_tested_sample)
        test.append([n_dimension, n_tested_sample, detection])
results_simple = pd.DataFrame(test, columns=["n_dimension", "n_tested_sample(%)", "detection_number"])
print(results_simple)
# Out:
# Please find the data used on results/Generator_2020-12-03 13:41:11.399144/Generator_2020-12-03 13:41:11.399144_dataUsed.csv
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.1*******
# Number of detections: 6
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.2*******
# Number of detections: 7
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.30000000000000004*******
# Number of detections: 16
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.4*******
# Number of detections: 26
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.5*******
# Number of detections: 28
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.6*******
# Number of detections: 33
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.7000000000000001*******
# Number of detections: 35
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.8*******
# Number of detections: 39
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.9*******
# Number of detections: 45
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.1*******
# Number of detections: 8
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.2*******
# Number of detections: 15
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.30000000000000004*******
# Number of detections: 24
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.4*******
# Number of detections: 30
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.5*******
# Number of detections: 35
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.6*******
# Number of detections: 42
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.7000000000000001*******
# Number of detections: 43
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.8*******
# Number of detections: 49
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.9*******
# Number of detections: 58
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.1*******
# Number of detections: 9
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.2*******
# Number of detections: 19
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.30000000000000004*******
# Number of detections: 27
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.4*******
# Number of detections: 33
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.5*******
# Number of detections: 41
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.6*******
# Number of detections: 44
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.7000000000000001*******
# Number of detections: 46
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.8*******
# Number of detections: 55
#
# ****NDKSWIN Execution Random with n_dimension = 3 n_tested_sample = 0.9*******
# Number of detections: 62
#     n_dimension  n_tested_sample(%)  detection_number
# 0             1                 0.1                 6
# 1             1                 0.2                 7
# 2             1                 0.3                16
# 3             1                 0.4                26
# 4             1                 0.5                28
# 5             1                 0.6                33
# 6             1                 0.7                35
# 7             1                 0.8                39
# 8             1                 0.9                45
# 9             2                 0.1                 8
# 10            2                 0.2                15
# 11            2                 0.3                24
# 12            2                 0.4                30
# 13            2                 0.5                35
# 14            2                 0.6                42
# 15            2                 0.7                43
# 16            2                 0.8                49
# 17            2                 0.9                58
# 18            3                 0.1                 9
# 19            3                 0.2                19
# 20            3                 0.3                27
# 21            3                 0.4                33
# 22            3                 0.5                41
# 23            3                 0.6                44
# 24            3                 0.7                46
# 25            3                 0.8                55
# 26            3                 0.9                62

# %% [markdown]
# ## Applied On Stream data containning anomalies

# %%
dataset_name = "AnomalySineGenerator"
test_name = dataset_name+'_'+str(datetime.datetime.now())

anomalies_percentage = 0.1
n_anomalies= int(max_sample*anomalies_percentage)
#print(str(n_anomalies))
stream = func.get_anomalies_data_generated(n_samples=max_sample, n_anomalies=n_anomalies, contextual=False,
                 n_contextual=0.0, shift=4, noise=0.0, replace=True, random_state=None)

file_path = func.save_stream_data_generated(stream=stream, window = window, result_folder=test_name, 
                                                 window_number = window_number)
test = []
for n_dimension in range(1,2+1,1):
    for n_tested_sample in np.arange(0.1, 1, 0.1):

        stream, stream2, stream3 = func.get_file_stream2(path=file_path)
        print("")
        print("****NDKSWIN Execution Random with n_dimension = "+str(n_dimension)+" n_tested_sample = "
              +str(n_tested_sample)+"*******")
        detection = execute_NDKSWIN(stream=stream3, window_size=window, window_number=window_number, 
                         n_dimensions=n_dimension, n_tested_samples=n_tested_sample)
        test.append([n_dimension, n_tested_sample, detection])
results_anomalies = pd.DataFrame(test, columns=["n_dimension", "n_tested_sample(%)", "detection_number"])
print(results_anomalies)
# Out:
# Please find the data used on results/AnomalySineGenerator_2020-12-03 13:40:31.272243/AnomalySineGenerator_2020-12-03 13:40:31.272243_dataUsed.csv
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.1*******
# Number of detections: 7
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.2*******
# Number of detections: 10
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.30000000000000004*******
# Number of detections: 11
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.4*******
# Number of detections: 22
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.5*******
# Number of detections: 20
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.6*******
# Number of detections: 26
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.7000000000000001*******
# Number of detections: 30
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.8*******
# Number of detections: 36
#
# ****NDKSWIN Execution Random with n_dimension = 1 n_tested_sample = 0.9*******
# Number of detections: 41
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.1*******
# Number of detections: 9
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.2*******
# Number of detections: 16
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.30000000000000004*******
# Number of detections: 20
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.4*******
# Number of detections: 26
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.5*******
# Number of detections: 34
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.6*******
# Number of detections: 35
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.7000000000000001*******
# Number of detections: 37
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.8*******
# Number of detections: 50
#
# ****NDKSWIN Execution Random with n_dimension = 2 n_tested_sample = 0.9*******
# Number of detections: 57
#     n_dimension  n_tested_sample(%)  detection_number
# 0             1                 0.1                 7
# 1             1                 0.2                10
# 2             1                 0.3                11
# 3             1                 0.4                22
# 4             1                 0.5                20
# 5             1                 0.6                26
# 6             1                 0.7                30
# 7             1                 0.8                36
# 8             1                 0.9                41
# 9             2                 0.1                 9
# 10            2                 0.2                16
# 11            2                 0.3                20
# 12            2                 0.4                26
# 13            2                 0.5                34
# 14            2                 0.6                35
# 15            2                 0.7                37
# 16            2                 0.8                50
# 17            2                 0.9                57
