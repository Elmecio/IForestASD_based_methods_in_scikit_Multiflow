# %% [markdown]
# # Comparison of Original IForestASD, SADWIN IFA, PADWIN IFA, and NDKSWIN

# %% [markdown]
# L'objectif est de voir comment les 4 méthodes se comportent avec différents jeux de données.
# * SAWIN IFA (Scores based ADWIN on IForestASD) utilise le score des données sur la base du modèle créé avec IForest ASD dans les fenêtres précédentes. Ce score est utilisé par ADWIN pour vérifier si le modèle drift pour pas. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.
# * PAWIN IFA (Prediction based ADWIN on IForestASD) utilise la classification des données sur la base du modèle créé avec IForest ASD dans les fenêtres précédentes. Cette classification est utilisée par ADWIN pour vérifier si le modèle drift pour pas. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.
# * NDKSWIN IFA (N-Dimensional KSWIN on IForestASD) utilise les données de la fenêtre courante pour détecter si elles drift sur au moins une colonne. NDKSWIN est une adaptation de KSWIN de scikit-multiflow pour les données à n dimensions. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.

# %% [markdown]
# ## Install skmultiflow if needed
# You need to install git

# %%
#print("scikit-multiflow package installation")
#!pip install -U git+https://github.com/scikit-multiflow/scikit-multiflow

# %%
try:
    import skmultiflow
except ImportError as e:
    print("scikit-multiflow package installation")
    # !pip install -U git+https://github.com/scikit-multiflow/scikit-multiflow

# %% [markdown]
# ## Importations and configurations

# %%
# %matplotlib notebook
import matplotlib as plt
plt.interactive(True)
from source import functions
func = functions.Comparison()
import datetime
#from skmultiflow.data import AnomalySineGenerator

# %% [markdown]
# ## General parameters for the evaluation

# %%
#************************ Execution settings *******************************
window_sizes = [100, 500]
n_estimators = [30]
#window_sizes = [50, 100]
#n_estimators = [20, 30]
#window_sizes = [50]
#n_estimators = [30]
#max_sample = 1000 # Total size of data to examine (windows number = max_sample/window)
#window = 100 # Number of sample in one window, window size.
#n_estimator = 30 # Number of itree in the random forest
execution_number = 1 # Number of execution because of the random character of IForest
anomaly_threshold = 0.5 # Anomaly threshold to decide which is anomaly or not
max_sample = 10000 # Total size of data to examine (windows number = max_sample/window)
n_wait = max_sample # The evaluation step size
# Used metric in the evaluation. Attention to use the metrics availlable in skmultiflow
metrics=['accuracy', 'f1', 'precision', 'recall', 'true_vs_predicted', 'kappa', 'kappa_m', 'running_time', 'model_size']

#************************ Stream data settings *******************************
window_save_size = 100
window_number = round((max_sample/window_save_size),0) # The number of window to save on .csv file

# Parameters for NDWSIN IFA
alpha=0.01
n_dimensions=2 # Number of dimensions to use for the test of the drift concept (normally 50% of m)
n_tested_samples=0.1 # Percentage of data to pick in the window to test the drift concept
fixed_checked_dimension = False # IF False, dimension will be choose randomly, if not on the 
fixed_checked_sample=False

# %% [markdown]
# ## Execution Function

# %%
def execute_comparision():
    for window in window_sizes:
        stream = func.get_dataset(dataset_name=dataset_name)
        for n_estimator in n_estimators:
            print("")
            print("******************************** Window = "+str(window)+" and n_estimator = "+str(n_estimator)+" ********************************")
            func.run_IForestASDs_comparison2(execution_number=execution_number, stream=stream, 
                                            stream_n_features=stream.n_features, window = window, 
                             estimators = n_estimator, anomaly = anomaly_threshold, drift_rate = drift_rate, 
                             result_folder=test_name, max_sample=max_sample, n_wait=n_wait, metrics=metrics,
                             #n_estimators_updated=n_estimators_updated, updated_randomly=updated_randomly,
                            alpha=alpha, n_dimensions=n_dimensions, n_tested_samples=n_tested_samples,
                            fixed_checked_dimension = fixed_checked_dimension, fixed_checked_sample=fixed_checked_sample)
    
    directory_path = 'results/'+str(test_name)
    func.merge_file2(folder_path=directory_path, output_file = 'output.csv',skiprows=(4 + 4))

# %% [markdown]
# ## Applied On Simple Stream Dataset
# ### Idea and waitting results
# ### Results
# #### Model updating
# #### Method performances
#
# ### Summary

# %%
metrics=['accuracy', 'f1', 'precision', 'recall', 'running_time', 'model_size']
dataset_name = "SMTP"
test_name = dataset_name+'_'+str(datetime.datetime.now())
drift_rate = 0.03

execute_comparision()
# Out:
# ******************************** Window = 100 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
# /home/momo/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:6265: RuntimeWarning: ks_2samp: Exact calculation incurred large rounding error. Switching to mode=asymp
#   RuntimeWarning)
#  #------------------- [5%] [94.19s]
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [215.72s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : SADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [350.89s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ####---------------- [20%] [489.52s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : SADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  #####--------------- [25%] [614.76s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [743.62s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  #######------------- [35%] [869.79s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : SADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [1019.27s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [1155.84s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [1286.34s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [1428.59s]
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [1571.00s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : SADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [1703.91s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ##############------ [70%] [1840.42s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###############----- [75%] [1973.40s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : SADWIN
#  ################---- [80%] [2109.07s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [2251.71s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ##################-- [90%] [2390.21s]
# The model was updated by training a new iForest with the version : SADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ###################- [95%] [2525.87s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [2657.27s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.7181
# O_IFA - Precision: 0.3333
# O_IFA - Recall: 0.2394
# O_IFA - F1 score: 0.3715
# O_IFA - Training time (s)  : 6.44
# O_IFA - Testing time  (s)  : 691.13
# O_IFA - Total time    (s)  : 697.57
# O_IFA - Size (kB)          : 330.7402
# SADWIN_IFA - Accuracy     : 0.5901
# SADWIN_IFA - Precision: 0.3333
# SADWIN_IFA - Recall: 0.1967
# SADWIN_IFA - F1 score: 0.3299
# SADWIN_IFA - Training time (s)  : 4.76
# SADWIN_IFA - Testing time  (s)  : 634.21
# SADWIN_IFA - Total time    (s)  : 638.97
# SADWIN_IFA - Size (kB)          : 249.9619
# PADWIN_IFA - Accuracy     : 0.5961
# PADWIN_IFA - Precision: 0.3333
# PADWIN_IFA - Recall: 0.1987
# PADWIN_IFA - F1 score: 0.3320
# PADWIN_IFA - Training time (s)  : 4.98
# PADWIN_IFA - Testing time  (s)  : 669.93
# PADWIN_IFA - Total time    (s)  : 674.91
# PADWIN_IFA - Size (kB)          : 296.0049
# NDKSWIN_IFA - Accuracy     : 0.6165
# NDKSWIN_IFA - Precision: 0.3333
# NDKSWIN_IFA - Recall: 0.2055
# NDKSWIN_IFA - F1 score: 0.3390
# NDKSWIN_IFA - Training time (s)  : 0.44
# NDKSWIN_IFA - Testing time  (s)  : 644.76
# NDKSWIN_IFA - Total time    (s)  : 645.20
# NDKSWIN_IFA - Size (kB)          : 266.7656
#
# Please find the result on results/SMTP_2020-12-13 20:32:00.691768/result_Number0_for_WS100_NE30updated_count.csv
#
# Please find evaluation results here results/SMTP_2020-12-13 20:32:00.691768/result_Number0_for_WS100_NE30.csv
#
# ******************************** Window = 500 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  #------------------- [5%] [0.03s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [705.72s]
# The model was updated by training a new iForest with the version : AnomalyRate
# /home/momo/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:6265: RuntimeWarning: ks_2samp: Exact calculation incurred large rounding error. Switching to mode=asymp
#   RuntimeWarning)
#  ###----------------- [15%] [1427.92s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ####---------------- [20%] [2202.19s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  #####--------------- [25%] [2968.99s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [3706.25s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [4445.20s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [5240.71s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : SADWIN
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  #########----------- [45%] [6175.04s]
# The model was updated by training a new iForest with the version : AnomalyRate
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ##########---------- [50%] [7076.69s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [7979.33s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [8882.59s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : SADWIN
#  #############------- [65%] [9757.86s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ##############------ [70%] [10620.63s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  ################---- [80%] [12343.74s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : SADWIN
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  #################--- [85%] [13238.63s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [14129.44s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [14977.43s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  #################### [100%] [15810.77s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.8431
# O_IFA - Precision: 0.3333
# O_IFA - Recall: 0.2810
# O_IFA - F1 score: 0.4066
# O_IFA - Training time (s)  : 6.66
# O_IFA - Testing time  (s)  : 4195.42
# O_IFA - Total time    (s)  : 4202.08
# O_IFA - Size (kB)          : 956.2402
# SADWIN_IFA - Accuracy     : 0.8361
# SADWIN_IFA - Precision: 0.3333
# SADWIN_IFA - Recall: 0.2787
# SADWIN_IFA - F1 score: 0.4048
# SADWIN_IFA - Training time (s)  : 5.62
# SADWIN_IFA - Testing time  (s)  : 3927.21
# SADWIN_IFA - Total time    (s)  : 3932.83
# SADWIN_IFA - Size (kB)          : 1071.9033
# PADWIN_IFA - Accuracy     : 0.7916
# PADWIN_IFA - Precision: 0.3333
# PADWIN_IFA - Recall: 0.2639
# PADWIN_IFA - F1 score: 0.3927
# PADWIN_IFA - Training time (s)  : 5.52
# PADWIN_IFA - Testing time  (s)  : 3856.69
# PADWIN_IFA - Total time    (s)  : 3862.21
# PADWIN_IFA - Size (kB)          : 688.5479
# NDKSWIN_IFA - Accuracy     : 0.7658
# NDKSWIN_IFA - Precision: 0.3333
# NDKSWIN_IFA - Recall: 0.2553
# NDKSWIN_IFA - F1 score: 0.3855
# NDKSWIN_IFA - Training time (s)  : 0.37
# NDKSWIN_IFA - Testing time  (s)  : 3812.50
# NDKSWIN_IFA - Total time    (s)  : 3812.87
# NDKSWIN_IFA - Size (kB)          : 732.2148
#
# Please find the result on results/SMTP_2020-12-13 20:32:00.691768/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/SMTP_2020-12-13 20:32:00.691768/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/SMTP_2020-12-13 20:32:00.691768/output.csv_full.csv

# %%
metrics=['accuracy', 'f1', 'precision', 'recall', 'running_time', 'model_size']
dataset_name = "Shuttle"
test_name = dataset_name+'_'+str(datetime.datetime.now())
drift_rate = 7.15

execute_comparision()
# Out:
# ******************************** Window = 100 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  #------------------- [5%] [146.06s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  #############------- [65%] [2311.94s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  ##############------ [70%] [2490.92s]
# /home/momo/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:6265: RuntimeWarning: ks_2samp: Exact calculation incurred large rounding error. Switching to mode=asymp
#   RuntimeWarning)
#  #################--- [85%] [3040.55s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  #################### [100%] [3584.40s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.9174
# O_IFA - Precision: 0.4963
# O_IFA - Recall: 0.6292
# O_IFA - F1 score: 0.7203
# O_IFA - Training time (s)  : 6.18
# O_IFA - Testing time  (s)  : 900.45
# O_IFA - Total time    (s)  : 906.63
# O_IFA - Size (kB)          : 479.8418
# SADWIN_IFA - Accuracy     : 0.9313
# SADWIN_IFA - Precision: 0.5142
# SADWIN_IFA - Recall: 0.6333
# SADWIN_IFA - F1 score: 0.7424
# SADWIN_IFA - Training time (s)  : 6.51
# SADWIN_IFA - Testing time  (s)  : 907.71
# SADWIN_IFA - Total time    (s)  : 914.22
# SADWIN_IFA - Size (kB)          : 511.4814
# PADWIN_IFA - Accuracy     : 0.9257
# PADWIN_IFA - Precision: 0.5066
# PADWIN_IFA - Recall: 0.6335
# PADWIN_IFA - F1 score: 0.7339
# PADWIN_IFA - Training time (s)  : 6.35
# PADWIN_IFA - Testing time  (s)  : 889.74
# PADWIN_IFA - Total time    (s)  : 896.09
# PADWIN_IFA - Size (kB)          : 493.9971
# NDKSWIN_IFA - Accuracy     : 0.9001
# NDKSWIN_IFA - Precision: 0.4782
# NDKSWIN_IFA - Recall: 0.6221
# NDKSWIN_IFA - F1 score: 0.6955
# NDKSWIN_IFA - Training time (s)  : 0.83
# NDKSWIN_IFA - Testing time  (s)  : 866.08
# NDKSWIN_IFA - Total time    (s)  : 866.91
# NDKSWIN_IFA - Size (kB)          : 511.1719
#
# Please find the result on results/Shuttle_2020-12-14 01:39:49.830003/result_Number0_for_WS100_NE30updated_count.csv
#
# Please find evaluation results here results/Shuttle_2020-12-14 01:39:49.830003/result_Number0_for_WS100_NE30.csv
#
# ******************************** Window = 500 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  ##------------------ [10%] [1151.70s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  ##############------ [70%] [14995.42s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  #################### [100%] [21893.64s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.9281
# O_IFA - Precision: 0.5906
# O_IFA - Recall: 0.6068
# O_IFA - F1 score: 0.7966
# O_IFA - Training time (s)  : 7.72
# O_IFA - Testing time  (s)  : 5460.17
# O_IFA - Total time    (s)  : 5467.89
# O_IFA - Size (kB)          : 1430.8652
# SADWIN_IFA - Accuracy     : 0.9325
# SADWIN_IFA - Precision: 0.6001
# SADWIN_IFA - Recall: 0.6189
# SADWIN_IFA - F1 score: 0.8108
# SADWIN_IFA - Training time (s)  : 7.56
# SADWIN_IFA - Testing time  (s)  : 5478.36
# SADWIN_IFA - Total time    (s)  : 5485.92
# SADWIN_IFA - Size (kB)          : 1471.8721
# PADWIN_IFA - Accuracy     : 0.9293
# PADWIN_IFA - Precision: 0.5893
# PADWIN_IFA - Recall: 0.6195
# PADWIN_IFA - F1 score: 0.8028
# PADWIN_IFA - Training time (s)  : 7.47
# PADWIN_IFA - Testing time  (s)  : 5485.08
# PADWIN_IFA - Total time    (s)  : 5492.54
# PADWIN_IFA - Size (kB)          : 1467.4033
# NDKSWIN_IFA - Accuracy     : 0.9298
# NDKSWIN_IFA - Precision: 0.5942
# NDKSWIN_IFA - Recall: 0.6118
# NDKSWIN_IFA - F1 score: 0.8022
# NDKSWIN_IFA - Training time (s)  : 0.39
# NDKSWIN_IFA - Testing time  (s)  : 5446.13
# NDKSWIN_IFA - Total time    (s)  : 5446.51
# NDKSWIN_IFA - Size (kB)          : 1464.9609
#
# Please find the result on results/Shuttle_2020-12-14 01:39:49.830003/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/Shuttle_2020-12-14 01:39:49.830003/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/Shuttle_2020-12-14 01:39:49.830003/output.csv_full.csv

# %%
metrics=['accuracy', 'f1', 'precision', 'recall', 'running_time', 'model_size']
dataset_name = "ForestCover"
test_name = dataset_name+'_'+str(datetime.datetime.now())
drift_rate = 0.96

execute_comparision()
# Out:
# ******************************** Window = 100 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  #------------------- [5%] [143.45s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ##------------------ [10%] [310.05s]
# The model was updated by training a new iForest with the version : SADWIN
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ###----------------- [15%] [475.93s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ####---------------- [20%] [646.67s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  #####--------------- [25%] [810.04s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ######-------------- [30%] [973.00s]
# The model was updated by training a new iForest with the version : SADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  #######------------- [35%] [1145.21s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ########------------ [40%] [1305.50s]
# The model was updated by training a new iForest with the version : SADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : SADWIN
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  #########----------- [45%] [1472.28s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ##########---------- [50%] [1636.75s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ###########--------- [55%] [1808.00s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  ############-------- [60%] [1980.54s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  #############------- [65%] [2157.04s]
# The model was updated by training a new iForest with the version : SADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ###############----- [75%] [2515.98s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ################---- [80%] [2694.67s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  #################### [100%] [3426.03s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.6807
# O_IFA - Precision: 0.4532
# O_IFA - Recall: 0.5062
# O_IFA - F1 score: 0.5958
# O_IFA - Training time (s)  : 5.86
# O_IFA - Testing time  (s)  : 840.85
# O_IFA - Total time    (s)  : 846.71
# O_IFA - Size (kB)          : 638.5723
# SADWIN_IFA - Accuracy     : 0.3890
# SADWIN_IFA - Precision: 0.3017
# SADWIN_IFA - Recall: 0.2876
# SADWIN_IFA - F1 score: 0.3464
# SADWIN_IFA - Training time (s)  : 6.20
# SADWIN_IFA - Testing time  (s)  : 844.64
# SADWIN_IFA - Total time    (s)  : 850.84
# SADWIN_IFA - Size (kB)          : 620.3174
# PADWIN_IFA - Accuracy     : 0.4780
# PADWIN_IFA - Precision: 0.3329
# PADWIN_IFA - Recall: 0.3307
# PADWIN_IFA - F1 score: 0.4075
# PADWIN_IFA - Training time (s)  : 6.60
# PADWIN_IFA - Testing time  (s)  : 870.74
# PADWIN_IFA - Total time    (s)  : 877.33
# PADWIN_IFA - Size (kB)          : 640.8760
# NDKSWIN_IFA - Accuracy     : 0.4001
# NDKSWIN_IFA - Precision: 0.3101
# NDKSWIN_IFA - Recall: 0.2994
# NDKSWIN_IFA - F1 score: 0.3577
# NDKSWIN_IFA - Training time (s)  : 0.64
# NDKSWIN_IFA - Testing time  (s)  : 849.82
# NDKSWIN_IFA - Total time    (s)  : 850.46
# NDKSWIN_IFA - Size (kB)          : 640.8711
#
# Please find the result on results/ForestCover_2020-12-14 08:44:28.898167/result_Number0_for_WS100_NE30updated_count.csv
#
# Please find evaluation results here results/ForestCover_2020-12-14 08:44:28.898167/result_Number0_for_WS100_NE30.csv
#
# ******************************** Window = 500 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  ##------------------ [10%] [1179.93s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ###----------------- [15%] [2275.10s]
# The model was updated by training a new iForest with the version : SADWIN
#  ####---------------- [20%] [3362.40s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ######-------------- [30%] [5550.49s]
# The model was updated by training a new iForest with the version : SADWIN
# Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ########------------ [40%] [7883.06s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  #########----------- [45%] [8989.94s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  ##########---------- [50%] [10101.41s]
# The model was updated by training a new iForest with the version : SADWIN
#  ############-------- [60%] [12335.95s]
# The model was updated by training a new iForest with the version : NDKSWIN
#  #############------- [65%] [13486.68s]
# The model was updated by training a new iForest with the version : SADWIN
#  ##############------ [70%] [14667.80s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  #################--- [85%] [18182.84s]Change detected PADWIN
#
# The model was updated by training a new iForest with the version : PADWIN
#  #################### [100%] [21694.76s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.7826
# O_IFA - Precision: 0.5158
# O_IFA - Recall: 0.5610
# O_IFA - F1 score: 0.6962
# O_IFA - Training time (s)  : 7.53
# O_IFA - Testing time  (s)  : 5296.77
# O_IFA - Total time    (s)  : 5304.30
# O_IFA - Size (kB)          : 1950.7988
# SADWIN_IFA - Accuracy     : 0.5612
# SADWIN_IFA - Precision: 0.3486
# SADWIN_IFA - Recall: 0.3400
# SADWIN_IFA - F1 score: 0.4481
# SADWIN_IFA - Training time (s)  : 7.60
# SADWIN_IFA - Testing time  (s)  : 5452.13
# SADWIN_IFA - Total time    (s)  : 5459.73
# SADWIN_IFA - Size (kB)          : 2166.8486
# PADWIN_IFA - Accuracy     : 0.5848
# PADWIN_IFA - Precision: 0.3479
# PADWIN_IFA - Recall: 0.3368
# PADWIN_IFA - F1 score: 0.4510
# PADWIN_IFA - Training time (s)  : 8.01
# PADWIN_IFA - Testing time  (s)  : 5492.70
# PADWIN_IFA - Total time    (s)  : 5500.71
# PADWIN_IFA - Size (kB)          : 2002.5752
# NDKSWIN_IFA - Accuracy     : 0.5579
# NDKSWIN_IFA - Precision: 0.3251
# NDKSWIN_IFA - Recall: 0.3089
# NDKSWIN_IFA - F1 score: 0.4180
# NDKSWIN_IFA - Training time (s)  : 0.40
# NDKSWIN_IFA - Testing time  (s)  : 5428.82
# NDKSWIN_IFA - Total time    (s)  : 5429.22
# NDKSWIN_IFA - Size (kB)          : 2160.7266
#
# Please find the result on results/ForestCover_2020-12-14 08:44:28.898167/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/ForestCover_2020-12-14 08:44:28.898167/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/ForestCover_2020-12-14 08:44:28.898167/output.csv_full.csv
